# %% [markdown]
# # Sinusoidal vs RoPE
#
# Colab setup from the repository root:
#
# ```bash
# !curl -LsSf https://astral.sh/uv/install.sh | sh
# !uv sync
# ```

# %%
from forge_position import build_sinusoidal_table, build_rope_cache

sin_table = build_sinusoidal_table(16, 8)
cos, sin = build_rope_cache(16, 8)
sin_table.shape, cos.shape, sin.shape
