# %% [markdown]
# # KV-Cache Position Bugs
#
# Colab setup from the repository root:
#
# ```bash
# !curl -LsSf https://astral.sh/uv/install.sh | sh
# !uv sync
# ```

# %%
from forge_position import build_position_ids_for_decode, build_position_ids_for_prefill

prefill = build_position_ids_for_prefill(1, 5)
correct_decode = build_position_ids_for_decode(1, 5)
wrong_decode = build_position_ids_for_decode(1, 0)
prefill, correct_decode, wrong_decode
