# %% [markdown]
# # 03 — ALiBi Bias Visualization
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/marcoharuni/forge-position/blob/main/notebooks/03_alibi_bias_visualization.ipynb)
#
# Visualize Attention with Linear Biases and inspect how different heads receive different recency slopes.
#
# **Runtime:** <5 minutes on free Colab T4
#
# ---

# %% [markdown]
# ## 1. Install & Clone

# %%
# !curl -LsSf https://astral.sh/uv/install.sh | sh
# !git clone https://github.com/marcoharuni/forge-position.git
# %cd forge-position
# !/root/.local/bin/uv sync

# %% [markdown]
# ## 2. Imports

# %%
import sys
sys.path.insert(0, 'src')

import torch

from forge_position import build_alibi_bias, get_alibi_slopes, plot_alibi_bias

print(torch.__version__)

# %% [markdown]
# ## 3. Slopes

# %%
slopes = get_alibi_slopes(6)
print(slopes)

# %% [markdown]
# ## 4. Bias matrix

# %%
bias = build_alibi_bias(n_heads=6, query_len=32, key_len=32)
print(bias.shape)
plot_alibi_bias(bias)

# %% [markdown]
# ## 5. Monotonic recency penalty

# %%
last_query = bias[0, 0, -1]
print(last_query[:8])
print('older keys are more negative:', bool(last_query[0] < last_query[1] < last_query[2]))

# %% [markdown]
# ---
#
# **Next →** [04_kv_cache_position_bugs.ipynb](04_kv_cache_position_bugs.ipynb)
