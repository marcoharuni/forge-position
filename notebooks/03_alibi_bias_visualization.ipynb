# %% [markdown]
# # ALiBi Bias Visualization
#
# Colab setup from the repository root:
#
# ```bash
# !curl -LsSf https://astral.sh/uv/install.sh | sh
# !uv sync
# ```

# %%
from forge_position import build_alibi_bias, get_alibi_slopes, plot_alibi_bias

bias = build_alibi_bias(4, 16, 16)
get_alibi_slopes(4), plot_alibi_bias(bias)
